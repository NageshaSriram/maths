# %% [markdown]
# 2. Section B (40 marks)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy.linalg as la
from numpy.linalg import inv ,det
from numpy import linalg as LA

from sympy import Symbol, Derivative
from sklearn.datasets import load_diabetes
from sklearn.preprocessing import StandardScaler
from PIL import Image, ImageFilter, ImageOps

# %% [markdown]
# (a)
# Consider the following matrices:
# \begin{align}
# A = \begin{bmatrix} 2 & 4 \\
#         1 & 3
#         \end{bmatrix}
# \end{align}
#
# \begin{align}
# B = \begin{bmatrix} 5 & 6 \\
#               7 & 8
#     \end{bmatrix}
# \end{align}
#
# 1.  Find the result of the matrix addition \( A + B \).
# 2.  Calculate the matrix multiplication \( A $\times$ B \).
# 3.  Find the transpose of matrix \( A \).
# 4.  Calculate the determinant of matrix \( B \).
# 5.  Verify if matrix \( A \) is invertible by calculating its determinant and, if it is invertible, find the inverse of \( A \).
#
# (7 marks)

# %% [markdown]
# (b) Find Eigen Values of $A^{2}$, $A^{3}$ and $A^{-1}$for
# \begin{align}
# A=\begin{bmatrix}
# 5 & 9 & 1\\
# 6 & 1 & 2\\
# 4 & 1 & 3
# \end{bmatrix}
# \end{align}
#
# (7 marks)

# %% [markdown]
# (d) Find singular value decomposition of
# \begin{align}
# A = \begin{bmatrix}
# 11 & 12\\
# 30 & 40\\
# 15 & 26
# \end{bmatrix}
# \end{align}
#
# (6 marks)

# %% [markdown]
# (c) Find the scalar and vector projections of the vector u = 2i - j on vector v = 3i +9j
#
# (6 marks )

# %% [markdown]
# (e)
# Consider a function $f(x) = x^2 + 4x + 5$.
#
# 1. Derive the gradient (first derivative) of $f(x)$.
# 2. Suppose the current point is x = 2. Calculate the gradient at this point.
# 3. If we apply one step of gradient descent from x = 2 with a learning rate α = 0.1, calculate the updated value of x.
# 4.  Explain why gradient descent moves towards a minimum in this function.
#
# (7 marks)

# %% [markdown]
# (f) Find the critical points of the function  $𝑓(x) =  x^3 + 5x^2+8x-2$
#
# (7 marks)

# %% [markdown]
# 3. Section C (40 marks)

# %% [markdown]
# (a) Perform the transformation operations on the given image mentioned the following:
#
# 1. Apply grayscale transformation
#
# 2. Apply Median blur filter
#
# 3. Apply edge detection (canny filter)
#
# 4. Rotate the image by 90 degrees
#
# 5.  Scale the image by a factor of 1.5
#
# 6. Translate the image with the factors(0.2 in the x-direction, 0.1 in the y-direction).
#
# (10 marks)

# %%
# Step 1: Load the image
# Check the path of the dataset in your system and change accordingly
image_path = "/ESA_MF_QP_Oct24/Question/cheeta.jpg"
image = Image.open(image_path)

# 1. Apply grayscale transformation

# 2. Apply median blur filter


# 3. Apply edge detection (simple edge detection using filters)


# 4. Rotate the image by 90 degrees

# 5. Scale the image by a factor of 1.5

# 6. Translate the image (0.2 in x-direction, 0.1 in y-direction)
# Create a new image with a transparent background

# Display the final transformed image

# %% [markdown]
# b). Apply PCA step by step to the following dataset and select the PCs that capture 95% of variance. The given dataset id a breast cancer dataset.
#
# Features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass. They describe characteristics of the cell nuclei present in the image.
#
# Attribute Information:
#
#     1) ID number
#     2) Diagnosis (M = malignant, B = benign) (target variable)
#
# Data Description
#
#     a) radius (mean of distances from center to points on the perimeter)
#     b) texture (standard deviation of gray-scale values)
#     c) perimeter
#     d) area
#     e) smoothness (local variation in radius lengths)
#     f) compactness (perimeter^2 / area - 1.0)
#     g) concavity (severity of concave portions of the contour)
#     h) concave points (number of concave portions of the contour)
#     i) symmetry
#     j) fractal dimension ("coastline approximation" - 1)
#
#
#
# (15 marks )

# %%
# Step 1: Load the diabetes dataset
# Check the path of the dataset in your system and change accordingly

# %%
df=pd.read_csv('/ESA_MF_QP_Oct24/Question/cancer_data.csv',index_col=0)
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Step 2: Standardize the Data

# Step 3: Compute the Covariance Matrix

# Step 4: Compute the Eigenvectors and Eigenvalues

# Step 5: Select Principal Components

# Sort eigenvalues and eigenvectors in descending order

# Select the top k eigenvectors based on the explained variance ratio

# Step 6: Project Data onto Principal Components


# Display the explained variance ratio and cumulative explained variance ratio

# %% [markdown]
# (c)
# A particle travels along the path given by the function f(x) = 2sin(x) + 3cos(x), where x represents time in seconds.
#
# 1. Plot the path function of the particle.
# 2. Find the rate of change of the path of the particle:
#    - Using the limit concept.
#    - Using the differential function.
# 3. Plot the rate of change of the path of the particle.
# 4. Plot the rate of change of path of the particle at x = 60° (or π/3 radians):
#    - Using the limit concept.
#    - Using the differential function.
# 5. Plot the rate of change of the path of the particle at x = 60°.
#
#
# (15 marks)
