# %% [markdown]
# ## Question 1 : PCA

# %% [markdown]
# ### 1.A. Read the data S3TH_1.

# %%
from numpy import array
from numpy import mean
from numpy import cov
from numpy.linalg import eig

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
data = pd.read_csv("S3TH_1.csv")
data.head()
# Out:
#    X  Y  month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5      3    6  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4     10    3  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4     10    7  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6      3    6  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6      3    1  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %% [markdown]
# ### 1.B. Print out the number of features in the dataset.

# %%
data.shape
# Out:
# (517, 13)

# %% [markdown]
# ### 1.C. Conduct the PCA step by step for the given dataset

# %% [markdown]
# ### 1.C.1 define a matrix with the dataframe

# %%
data = np.array(data)

# %% [markdown]
# ### 1.C.2 calculate the mean of each column

# %%
M = mean(data.T, axis=1)
print(M)
# Out:
# [4.66924565e+00 4.29980658e+00 7.47582205e+00 3.97292070e+00
#  9.06446809e+01 1.10872340e+02 5.47940039e+02 9.02166344e+00
#  1.88891683e+01 4.42882012e+01 4.01760155e+00 2.16634429e-02
#  1.28472921e+01]

# %% [markdown]
# ### 1.C.3 center columns by subtracting column means

# %%
C = data - M
print(C)
# Out:
# [[  2.33075435   0.70019342  -4.47582205 ...   2.68239845  -0.02166344
#   -12.84729207]
#  [  2.33075435  -0.29980658   2.52417795 ...  -3.11760155  -0.02166344
#   -12.84729207]
#  [  2.33075435  -0.29980658   2.52417795 ...  -2.71760155  -0.02166344
#   -12.84729207]
#  ...
#  [  2.33075435  -0.29980658   0.52417795 ...   2.68239845  -0.02166344
#    -1.68729207]
#  [ -3.66924565  -0.29980658   0.52417795 ...  -0.01760155  -0.02166344
#   -12.84729207]
#  [  1.33075435  -1.29980658   3.52417795 ...   0.48239845  -0.02166344
#   -12.84729207]]

# %% [markdown]
# ### 1.C.4 Find the covariance between the features

# %%
V = cov(C.T)
print(V)
# Out:
# [[ 5.35356784e+00  1.53540102e+00 -3.42314786e-01  6.46694556e-02
#   -2.68720106e-01 -7.17001897e+00 -4.93132818e+01  6.55124976e-02
#   -6.88667101e-01  3.21760155e+00  7.79260942e-02  4.47760635e-02
#    9.33573051e+00]
#  [ 1.53540102e+00  1.51265500e+00 -1.85566701e-01 -3.45013720e-02
#   -3.14390566e-01  6.12959756e-01 -3.08690039e+01 -1.37321383e-01
#   -1.72133882e-01  1.24869926e+00 -4.48221702e-02  1.20972216e-02
#    3.51313901e+00]
#  [-3.42314786e-01 -1.85566701e-01  5.18013135e+00 -1.82826534e-01
#    3.66203200e+00  6.80224889e+01  4.90463470e+02  1.93637751e+00
#    4.87454381e+00 -3.53856102e+00 -3.52189885e-01  9.05192449e-03
#    8.18510882e+00]
#  [ 6.46694556e-02 -3.45013720e-02 -1.82826534e-01  4.59616452e+00
#    8.70979713e-01  3.94033482e+00  1.01717159e+00  3.51169163e-01
#    4.01256504e-01 -2.91466121e+00 -1.54139115e-02 -1.53037050e-02
#    6.59957769e+00]
#  [-2.68720106e-01 -3.14390566e-01  3.66203200e+00  8.70979713e-01
#   -1.34871917e-03]]
# [6.35429187e+04 4.05438105e+03 2.12203428e+03 2.72892308e+02
#  3.00890399e+01 1.46951635e+01 9.91607586e+00 5.74085246e+00
#  4.53621307e+00 8.35144582e-02 1.07380665e+00 8.67175045e-01
#  2.79965153e+00]

# %% [markdown]
# ### 1.C.6 project data

# %%
P = vectors.T.dot(C.T)
print(P.T)
# Out:
# [[-4.61769902e+02 -6.73646044e+00  1.16684738e+00 ...  1.04479084e+00
#   -7.55441770e-01  1.50570572e+00]
#  [ 1.05469326e+02 -2.15847427e+01  9.51530322e+01 ... -1.89140337e-01
#    1.30151938e+00 -2.55456570e+00]
#  [ 1.24425881e+02 -2.14786789e+01  9.02509659e+01 ... -1.74822986e-01
#    1.17373103e+00 -2.49830852e+00]
#  ...
#  [ 1.05845455e+02 -9.45321419e+00  7.26146211e+01 ...  1.44340953e+00
#   -1.80484543e-02  4.22659518e+00]
#  [ 7.19148185e+01 -1.19395955e+01 -2.36221888e+01 ... -1.05040653e+00
#   -3.48315814e-01  7.84815658e-01]
#  [-4.53650188e+02 -8.45316893e+00  2.75039899e+01 ... -3.87799009e+00
#    5.54215192e+00  1.09087639e+00]]

# %% [markdown]
# ### 1.C.7 create the PCA instance

# %%
pca = PCA(n_components=5)

# %% [markdown]
# ### 1.C.8 fit on data

# %%
pca.fit(data)
# Out:
# PCA(n_components=5)

# %% [markdown]
# ### 1.C.9 access values and vectors

# %%
print(pca.components_)
print(pca.explained_variance_)
# Out:
# [[-7.81889842e-04 -4.75474493e-04  7.78758421e-03  2.85885252e-05
#    7.39873554e-03  1.79469509e-01  9.83526564e-01  4.26931780e-03
#    1.15750401e-02 -2.27767362e-03 -1.43411817e-03  4.47461206e-05
#    1.38026418e-02]
#  [ 2.48834352e-03  1.08111278e-03 -6.52839245e-05  1.70409255e-03
#    3.02594061e-03  7.44526007e-02 -2.77236406e-02  5.29367906e-04
#    7.50584770e-03 -1.80811829e-02  7.28788502e-04 -2.78980698e-05
#    9.96636697e-01]
#  [ 5.69391415e-04  2.77167995e-03 -1.00324804e-02  1.43221351e-03
#    2.37827297e-02  9.78597816e-01 -1.77748561e-01  1.94461891e-02
#    1.84992591e-02  5.82001997e-02  1.99365893e-03  4.54434976e-04
#   -7.72244515e-02]
#  [ 1.17933924e-02  3.45372408e-03 -4.12774454e-03 -1.13312707e-02
#   -1.21256636e-01 -4.55283376e-02  1.37875957e-02 -5.43566445e-02
#   -2.00563295e-01  9.69005413e-01  6.54687303e-03  1.45194860e-03
#    2.32532343e-02]
#  [ 2.73862342e-02 -2.09925393e-03  8.66837431e-03  1.16109762e-02
#    7.35209447e-01 -4.39487025e-02 -2.13614548e-03  6.25503103e-01
#    1.92379200e-01  1.64423635e-01  3.51331888e-02  5.38064981e-03
#    2.08250938e-03]]
# [6.35429187e+04 4.05438105e+03 2.12203428e+03 2.72892308e+02
#  3.00890399e+01]

# %% [markdown]
# ### 1.C.10 transform data

# %%
data_pca = pca.transform(data)
print(data_pca)
# Out:
# [[-461.76990203   -6.73646044   -1.16684738    6.74432541   -1.86882966]
#  [ 105.46932573  -21.58474273  -95.15303218   -5.81386884   -0.51542443]
#  [ 124.42588106  -21.47867895  -90.25096586   -5.30712597   -1.51181416]
#  ...
#  [ 105.84545541   -9.45321419  -72.61462111   30.06013631   -4.17761266]
#  [  71.91481846  -11.93959547   23.6221888    -5.20093093    3.32676284]
#  [-453.65018763   -8.45316893  -27.50398986  -11.13287316  -10.96549793]]

# %% [markdown]
# ### 1.C.11 Plot the variance explained by each PCA component

# %%
plt.plot(np.arange(1,6),pca.explained_variance_)
plt.show()

# %%
plt.plot(np.arange(1,6),pca.explained_variance_ratio_)
plt.show()

# %% [markdown]
# ## Question 2 : PCA

# %% [markdown]
# ### 2.A. Read the data S3TH_4.

# %%
from numpy import array
from numpy import mean
from numpy import cov
from numpy.linalg import eig

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
data = pd.read_excel("S3TH_4.xlsx")
data.head()
# Out:
#    age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter(%)  Jitter(Abs)  \
# 0   72    0     5.6431       28.199       34.398    0.00662     0.000034
# 1   72    0    12.6660       28.447       34.894    0.00300     0.000017
# 2   72    0    19.6810       28.695       35.389    0.00481     0.000025
# 3   72    0    25.6470       28.905       35.810    0.00528     0.000027
# 4   72    0    33.6420       29.187       36.375    0.00335     0.000020
#
#    Jitter:RAP  Jitter:PPQ5  Jitter:DDP  ...  Shimmer(dB)  Shimmer:APQ3  \
# 0     0.00401      0.00317     0.01204  ...        0.230       0.01438
# 1     0.00132      0.00150     0.00395  ...        0.179       0.00994
# 2     0.00205      0.00208     0.00616  ...        0.181       0.00734
# 3     0.00191      0.00264     0.00573  ...        0.327       0.01106
# 4     0.00093      0.00130     0.00278  ...        0.176       0.00679
#
#    Shimmer:APQ5  Shimmer:APQ11  Shimmer:DDA       NHR     HNR     RPDE  \
# 0       0.01309        0.01662      0.04314  0.014290  21.640  0.41888
# 1       0.01072        0.01689      0.02982  0.011112  27.183  0.43493
# 2       0.00844        0.01458      0.02202  0.020220  23.047  0.46222
# 3       0.01265        0.01963      0.03317  0.027837  24.445  0.48730
# 4       0.00929        0.01819      0.02036  0.011625  26.126  0.47188
#
#        DFA      PPE
# 0  0.54842  0.16006
# 1  0.56477  0.10810
# 2  0.54405  0.21014
# 3  0.57794  0.33277
# 4  0.56122  0.19361
#
# [5 rows x 21 columns]

# %%
data.shape
# Out:
# (5875, 21)

# %% [markdown]
# ### 2.B. Find the covariance matrix of the dataset

# %%
V = cov(data.T)
print(V)
# Out:
# [[ 7.78192810e+01 -1.70891357e-01  9.37466847e+00  1.96252252e+01
#    2.92891360e+01  1.14465967e-03  1.13294327e-05  2.82595105e-04
#    4.34494607e-04  8.48023728e-04  2.31446780e-02  2.25725257e-01
#    1.15501424e-02  1.32276004e-02  2.38435661e-02  3.46507499e-02
data_pca = pca.transform(data)
var = pca.explained_variance_ratio_
plt.plot(np.arange(1,data.shape[1]+1),var)
plt.show()

# %% [markdown]
# ### 2.E. Transform the dataset into that number of features(k)

# %%
pca = PCA(n_components=2)
pca.fit(data)
data_pca = pca.transform(data)

# %%
pca.explained_variance_ratio_.sum()
# Out:
# np.float64(0.9716041130789692)

# %% [markdown]
# ### 2.F. Find the covariance matrix of the transformed dataset

# %%
V = cov(data_pca.T)
print(V)
# Out:
# [[2.85750806e+03 1.31299201e-12]
#  [1.31299201e-12 1.87058807e+02]]

# %% [markdown]
# ### 2.G. Draw a proper visual representation of the covariance matrix

# %%
import seaborn as sns
sns.heatmap(V)
# Out:
# <Axes: >

# %% [markdown]
# # Question 3 : PCA

# %% [markdown]
# ### 3.A. Read the data S3TH_1.

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
data = pd.read_csv("S3TH_1.csv")
data.head()
# Out:
#    X  Y  month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5      3    6  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4     10    3  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4     10    7  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6      3    6  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6      3    1  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %% [markdown]
# ### 3.B. Print out the number of features in the dataset.

# %%
data.shape[1]
# Out:
# 13

# %%
# Find the correlation between the features

# %%
data = np.array(data)

# %%
data
# Out:
# array([[ 7.  ,  5.  ,  3.  , ...,  6.7 ,  0.  ,  0.  ],
#        [ 7.  ,  4.  , 10.  , ...,  0.9 ,  0.  ,  0.  ],
#        [ 7.  ,  4.  , 10.  , ...,  1.3 ,  0.  ,  0.  ],
#        ...,
#        [ 7.  ,  4.  ,  8.  , ...,  6.7 ,  0.  , 11.16],
#        [ 1.  ,  4.  ,  8.  , ...,  4.  ,  0.  ,  0.  ],
#        [ 6.  ,  3.  , 11.  , ...,  4.5 ,  0.  ,  0.  ]])

# %% [markdown]
# ### 3.C. Print out the amount of variation we loose with the reducton of 6 feature(one by one) from the dataset.

# %%
cum_var=[]
for i  in np.arange(data.shape[1]-1,data.shape[1]-7,-1):
    pca = PCA(n_components=i)
    pca.fit(data)
    data_pca = pca.transform(data)
    var = pca.explained_variance_ratio_
    cum_var.append(var.sum())
plt.plot(np.arange(1,7),cum_var)
plt.show()

# %% [markdown]
# ## Question 4 : PCA

# %% [markdown]
# ### 4.A. Read the data S3TH_2.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import skimage.io as io
from skimage.color import rgb2gray
from sklearn.decomposition import PCA

# %%
# read image in grayscale
img = io.imread('S3TH_2.png', as_gray=True)
plt.imshow(img)
plt.show()

# %% [markdown]
# ### 4.B. Print out the number of features in the dataset.

# %%
img.shape[1]
# Out:
# 517

# %%
img.shape
# Out:
# (332, 517)

# %% [markdown]
# ### 4.C. Print out the maximum numbers of feature we can lay off and still capture 90% of the total variation.

# %%
pca = PCA(n_components=len(img))
pca.fit(img)
# Out:
# PCA(n_components=332)

# %%
X_pca = pca.transform(img)

# %%
X_pca.shape
# Out:
# (332, 332)

# %%
pca.explained_variance_ratio_
# Out:
# array([2.65672801e-01, 1.18086659e-01, 5.91858620e-02, 4.73622694e-02,
#        1.64120900e-05, 1.59611478e-05, 1.53194865e-05, 1.52722559e-05,
#        1.48537994e-05, 1.46612853e-05, 1.42597848e-05, 1.36528494e-05,
#        1.30812989e-05, 1.29471284e-05, 1.27215679e-05, 1.25989359e-05,
#        1.18943349e-05, 1.16603295e-05, 1.11128182e-05, 1.03949474e-05,
#        1.02013546e-05, 1.00008264e-05, 9.89007578e-06, 9.25694522e-06,
#        8.94635249e-06, 8.54002741e-06, 8.13484598e-06, 7.93402106e-06,
#        7.79112639e-06, 7.25786309e-06, 6.98241925e-06, 6.89488876e-06,
#        6.67888005e-06, 6.25299878e-06, 5.96614312e-06, 5.83431973e-06,
#        5.46253837e-06, 5.18109911e-06, 4.82227775e-06, 4.56836509e-06,
#        4.52933773e-06, 4.17043329e-06, 3.91714776e-06, 3.85713595e-06,
#        3.72210340e-06, 3.32167464e-06, 2.79968286e-06, 2.15132036e-31])

# %%
cum_var=[]
for i in range(1,len(img)):
    pca = PCA(n_components=i)
    pca.fit(img)
    img_pca = pca.transform(img)
    var = pca.explained_variance_ratio_
    cum_var.append(var.sum())
plt.plot(range(1,len(img)),cum_var)
plt.show()

# %%
cum_var = np.array(cum_var)
len(cum_var[cum_var<.9])
# Out:
# 46

# %%
plt.plot(range(1,len(img)),cum_var)
plt.axhline(.90,color = 'red')
plt.axvline(len(cum_var[cum_var<.90]),color = 'black')
plt.show()

# %% [markdown]
# ### 4.D. Draw the amount of variation capture graph for each additional new features

# %%
pca = PCA(n_components=8)
pca.fit(img)
X_pca = pca.transform(img)
var = pca.explained_variance_ratio_
plt.plot(range(1,9),var)

# %% [markdown]
# # Question 5 : SVD

# %% [markdown]
# ### 5.A. Read the data S3TH_3.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import skimage.io as io
from skimage.color import rgb2gray

# %%
# read image in grayscale
img = io.imread('S3TH_3.png', as_gray=True)
plt.imshow(img)
plt.show()

# %% [markdown]
# ### 5.B. Print out the number of features in the dataset.

# %%
img.shape
# Out:
# (388, 397)

# %% [markdown]
# ### 5.C. Reduce the number of feature by 5% each time and show the visualise effect on the picture.

# %%
# obtain svd
U, S, V = np.linalg.svd(img)

# %%
# inspect shapes of the matrices
print(U.shape, S.shape, V.shape)
# Out:
# (388, 388) (388,) (397, 397)

# %%
len(S)
# Out:
# 388

# %%
# plot images with different number of components
index = np.arange(100,0,-5)
comp = index*len(S)/100
comps = list(map(lambda x:int(round(x)), comp))

plt.figure(figsize = (20, 15))
for i in range(len(comps)):
  low_rank = U[:, :comps[i]] @ np.diag(S[:comps[i]]) @ V[:comps[i], :]
  if(i  == 0):
     plt.subplot(4, 5, i+1), plt.imshow(low_rank, cmap = 'gray'), plt.axis('off'), plt.title("Original Image with n_components =" + str(comps[i]))
  else:
     plt.subplot(4, 5, i+1), plt.imshow(low_rank, cmap = 'gray'), plt.axis('off'), plt.title("n_components =" + str(comps[i]))

# %% [markdown]
# ## ----------------------------------------------HAPPY LEARNING---------------------------------------------------------
